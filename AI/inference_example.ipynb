# %%
from architecture.classification.pipeline import ClassificationPipeline
from architecture.classification.preprocessor import Preprocessor
from architecture.classification.embedder import MLEmbedder1
from architecture.classification.inferrer import Inferrer


preprocessor = Preprocessor()
embedder = MLEmbedder1()
inferrer = Inferrer()

classifier = ClassificationPipeline(
    preprocessor=
)
classifier.predict()
